# %%
#!pip install ultralytics

# %%
from ultralytics import YOLO

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.113 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/112.6 GB disk)

# %% [markdown]
# * Testing YOLO-11 model

# %%
model = YOLO("yolo11n.pt")

results = model.predict("/content/cars_road.mp4", imgsz=640, conf=0.3, save=True)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 171MB/s]
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/444) /content/cars_road.mp4: 384x640 4 persons, 6 cars, 1 bus, 4 trucks, 10.2ms
# video 1/1 (frame 2/444) /content/cars_road.mp4: 384x640 4 persons, 5 cars, 1 bus, 4 trucks, 17.3ms
# video 1/1 (frame 3/444) /content/cars_road.mp4: 384x640 2 persons, 6 cars, 1 bus, 4 trucks, 13.5ms
# ...

# %% [markdown]
# Testing YOLO-v10 model

# %%
model = YOLO("yolov10n.pt")

results = model.predict("/content/cars_road.mp4", save=True, imgsz=640, conf=0.3)
# Out:
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 171MB/s]
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/444) /content/cars_road.mp4: 384x640 2 persons, 5 cars, 1 bus, 3 trucks, 10.2ms
# video 1/1 (frame 2/444) /content/cars_road.mp4: 384x640 2 persons, 6 cars, 1 bus, 5 trucks, 14.2ms
# video 1/1 (frame 3/444) /content/cars_road.mp4: 384x640 2 persons, 7 cars, 1 bus, 5 trucks, 13.9ms
# ...

# %% [markdown]
# Testing YOLO-v8 model

# %%
model = YOLO("yolov8n.pt")

results = model.predict("/content/cars_road.mp4", save=True, imgsz=640, conf=0.3)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 199MB/s]
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/444) /content/cars_road.mp4: 384x640 1 person, 8 cars, 1 bus, 4 trucks, 7.7ms
# video 1/1 (frame 2/444) /content/cars_road.mp4: 384x640 2 persons, 8 cars, 1 bus, 4 trucks, 13.2ms
# video 1/1 (frame 3/444) /content/cars_road.mp4: 384x640 2 persons, 8 cars, 1 bus, 4 trucks, 10.2ms
# ...
